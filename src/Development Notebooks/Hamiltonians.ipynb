# %%
import qiskit_nature as q_nat

# %%
from qiskit_nature.second_q.hamiltonians.lattices import LineLattice, SquareLattice

# %%
L0 = SquareLattice(2,2)
L1 = SquareLattice(2,3)
L2 = SquareLattice(3,3)
L3 = SquareLattice(4,5)
L4 = SquareLattice(5,5)
L5 = SquareLattice(6,5)

# %%
from qiskit_nature.second_q.hamiltonians import HeisenbergModel, FermiHubbardModel
from qiskit_nature.second_q.mappers import JordanWignerMapper, LinearMapper, QubitMapper, LogarithmicMapper
JWmapper = JordanWignerMapper()
Linmapper = LinearMapper()
Qmapper = QubitMapper()
Logmapper = LogarithmicMapper()

# %%
H1 = HeisenbergModel(L3)
Linmapper.map(H1.second_q_op())
# Out:
# SparsePauliOp(['IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIXXXX', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIXXYY', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIYYXX', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIYYYY', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIXYXY', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIXYYX', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIYXXY', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIYXYX', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIZI', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIZ', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZZI', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIZ', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIXXIIIIIIXX', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIXXIIIIIIYY', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIYYIIIIIIXX', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIYYIIIIIIYY', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIXYIIIIIIXY', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIXYIIIIIIYX', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIYXIIIIIIXY', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIYXIIIIIIYX', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIZI', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIZ', 'IIIIIIIIIIIIII
# ...

# %%
H2 = HeisenbergModel(L4)
Linmapper.map(H2.second_q_op())
# Out:
# SparsePauliOp(['IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIXXXX', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIXXYY', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIYYXX', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIYYYY', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIXYXY', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIXYYX', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIYXXY', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIYXYX', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIZI', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIZ', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZZI', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIZ', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIXXIIIIIIIIXX', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIXXIIIIIIIIYY', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIYYIIIIIIIIXX', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIYYIIIIIIIIYY', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIXYIIIIIIIIXY', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIXYIIIIIIIIYX', 'IIIIIIIIII
# ...

# %%
H3 = HeisenbergModel(L5)
Linmapper.map(H3.second_q_op())
# Out:
# SparsePauliOp(['IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIXXXX', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIXXYY', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIYYXX', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIYYYY', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIXYXY', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIXYYX', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIYXXY', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIYXYX', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIZI', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIZ', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZZI', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIZ', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIXXIIIIIIIIIIXX', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIXXIIIIIIIIIIYY', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIYYIIIIIIIIIIXX', 'IIIIIIIIIIIIIIIIIIIIII
# ...

# %%
F1 = FermiHubbardModel(L3, onsite_interaction=5.0)
JWmapper.map(F1.second_q_op())
# Out:
# SparsePauliOp(['IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIYZY', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIXZX', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIYZZZZZZZY', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIXZZZZZZZX', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIYZYIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIXZXIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIYZZZZZZZYIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIXZZZZZZZXIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIYZYIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIXZXIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIYZZZZZZZYIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIXZZZZZZZXIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIYZYIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIXZXIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIYZZZZZZZYIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIXZZZZZZZXIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIYZYIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIXZXIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIYZYII', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIXZXII', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIYZZZZZZZYII', 'IIIIIIIIIIIIII
# ...

# %%
F2 = FermiHubbardModel(L4, onsite_interaction=5.0)
JWmapper.map(F2.second_q_op())
# Out:
# SparsePauliOp(['IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIYZY', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIXZX', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIYZZZZZZZZZY', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIXZZZZZZZZZX', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIYZYIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIXZXIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIYZZZZZZZZZYIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIXZZZZZZZZZXIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIYZYIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIXZXIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIYZZZZZZZZZYIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIXZZZZZZZZZXIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIYZYIIIIIIIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIXZXIIIIIIIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIYZZZZZZZZZYIIIIIIIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIXZZZZZZZZZXIIIIIIIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIYZYIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIXZX
# ...

# %%
F3 = FermiHubbardModel(L5, onsite_interaction=5.0)
JWmapper.map(F3.second_q_op())
# Out:
# SparsePauliOp(['IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIYZY', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIXZX', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIYZZZZZZZZZZZY', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIXZZZZZZZZZZZX', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIYZYIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIXZXIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIYZZZZZZZZZZZYIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIXZZZZZZZZZZZXIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIYZYIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIXZXIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIYZZZZZZZZZZZYIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIIIXZZZZZZZZZZZXIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIYZYIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIIIIIIIIIIIXZXIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII', 'IIIIIIIIIIIYZZZZZZZZZZ
# ...
