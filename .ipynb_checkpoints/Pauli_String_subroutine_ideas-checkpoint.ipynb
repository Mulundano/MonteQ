# %% [markdown]
# ### Purpose
# Given a Pauli string $p$ what is the shortest path to get it to be "implementable" (defined as a Pauli String with a Pauli weight of 1 and the single qubit operation being Z)?
# This is important to understand because solving this problem will create a subroutine for solving the shortest distance problem for a Pauli word $P = [p_{1}, p_{2}, ... p_{n}]$
#
# To solve this first, we shall find the shortest path in a graph of Pauli strings from an arbitrary Pauli string to an implementable Pauli string. The total number of possible nodes is on the scale of $4^{n + 1/2}$( the $1/2$ is to account for both positive and negative signs). Based on how, the paths form, an optimal or near optimal procedure can be made.

# %%
import networkx as nx
import numpy as np 
import random as rnd

# %%
# class that implements tableau and necessary operations
# Reference -Improved Simulation of Stabilizer Circuits by Scott Aaronson & Daniel Gottesman
class Cirq_Tableau:
    
    def __init__(
        self,
        pauli_word: list[str] = None  
    ):
        if pauli_word is None or len(pauli_word) == 0:
            self._column_num = None
            self._row_num = None

            self._ss, self._xs, self._zs = None, None, None
        else:
            if "-" in pauli_word[0]:
                self._column_num = len(pauli_word[0][1:]) 
            else:
                self._column_num = len(pauli_word[0])
            self._row_num = len(pauli_word)

            self._ss = self.create_sign(pauli_word)
            self._xs, self._zs = self.create_tab(pauli_word)

    # setters & getters 
    @property
    def ss(self) -> np.ndarray:
        return self._ss

    @ss.setter 
    def ss(self, new_ss: np.ndarray):
        self._ss = new_ss
        
    @property
    def xs(self) -> np.ndarray:
        return self._xs

    @xs.setter 
    def xs(self, new_xs: np.ndarray):
        self._xs = new_xs
        
    @property
    def zs(self) -> np.ndarray:
        return self._zs

    @zs.setter 
    def zs(self, new_zs: np.ndarray):
        self._zs = new_zs
        
    @property
    def column_num(self) -> int:
        return self._column_num

    @column_num.setter 
    def column_num(self, new_num: int):
        self._column_num = new_num
    
    @property
    def row_num(self) -> int:
        return self._row_num

    @row_num.setter 
    def row_num(self, new_num: int):
        self._row_num = new_num

    # functions that create parts of tableau
    def create_sign(self, pauli_word: list[str]):
        temp_ss = np.zeros((self.row_num), dtype=int)
        for pauli_string in pauli_word:
            if "-" in pauli_string:
                index = pauli_word.index(pauli_string)
                pauli_word[index] = pauli_string.replace("-", "")
                #print(pauli_word)
                temp_ss[index] = 1
        return temp_ss
        
    def create_tab(self, pauli_word: list[str]):
        temp_x = np.zeros((self.row_num, self.column_num), dtype=int)
        temp_z = np.zeros((self.row_num, self.column_num), dtype=int)
        for i, pauli_string in enumerate(pauli_word):
            for j, pauli in enumerate(pauli_string):
                if pauli == "X" or pauli == "Y":
                    temp_x[i][j] = 1
                if pauli == "Z" or pauli == "Y":
                    temp_z[i][j] = 1
        return temp_x, temp_z

    # Clifford operations on tableau. 
    def apply_H(self,column: int):
        self.ss ^= self.xs[:, column] & self.zs[:, column]
        self.xs[:, column], self.zs[:, column] = self.zs[:, column].copy(), self.xs[:, column].copy()

    def apply_S(self, column: int):
        self.ss ^= self.xs[:, column] & self.zs[:, column]
        self.zs[:, column] = self.xs[:, column] ^ self.zs[:, column]

    def apply_CX(self, control: int, target: int):
        self.ss ^= (
            (self.xs[:, control] & self.zs[:, target])
            &(~(self.xs[:, target] ^ self.zs[:, control]))
        )
        self.xs[:, target] ^= self.xs[:, control]
        self.zs[:, control] ^= self.zs[:, target]

    # class operations necessary for comparisons and equating
    def copy(self):
        new_tab = Cirq_Tableau()
        new_tab.column_num = self.column_num
        new_tab.row_num = self.row_num
        new_tab.ss = self.ss.copy()
        new_tab.zs = self.zs.copy()
        new_tab.xs = self.xs.copy()
        return new_tab
    
    def __eq__(self, other):
        if not isinstance(other, type(self)):
            return NotImplemented  
        return (
            self.column_num == other.column_num
            and self.row_num == other.row_num
            and np.array_equal(self.ss, other.ss)
            and np.array_equal(self.xs, other.xs)
            and np.array_equal(self.zs, other.zs)
        )
    
    def return_string(self):
        string = ''
        for i in range(self.row_num):
            if self.ss[i]:
                string += "-"  

            for j in range(self.column_num):
                if self.xs[i][j] and not self.zs[i][j]:
                    string += "X"
                elif not self.xs[i][j] and self.zs[i][j]:
                    string += "Z"
                elif self.xs[i][j] and self.zs[i][j]:
                    string += "Y"
                else:
                    string += "I"
            if i < self.row_num - 1:
                string += "\n" 

        return string
    
    def __copy__(self):
        return self.copy()
        

    def __str__(self) -> str:
        ss = np.expand_dims(self.ss, axis = 1)
        xz = np.concatenate((self.xs, self.zs, ss), axis=1)
        return str(xz)

    def __hash__(self) -> int:
        return hash(self.zs.tobytes() + self.xs.tobytes() + self.ss.tobytes())

    def __lt__(self, other):
        return self.row_num < other.row_num

# %%
def graph_creator(init: str, digraph):
    '''
    Function to create a full graph of all the possible Pauli strings

    :param init: initial Pauli string to grow the graph from
    :param digraph: networkX graph to populate
    '''
    open_list = [init]
    closed_list = []

    while open_list:
        node = open_list[0]
        tableau = Cirq_Tableau([node])
        closed_list.append(node)
        del open_list[0]
        num_qubits = tableau.column_num
        for i in range(num_qubits):
            if i != (num_qubits - 1):
                for j in range((i+1), num_qubits):
                    tab1, tab2 = tableau.copy(), tableau.copy()
                    tab1.apply_CX(i, j)
                    tab2.apply_CX(j, i)
                    next_node1, next_node2 = tab1.return_string(), tab2.return_string()
                    digraph.add_edge(node, next_node1, weight =1, label=("CX", i, j))
                    digraph.add_edge(node, next_node2, weight =1, label=("CX", j, i))
                    if next_node1 not in closed_list:
                        open_list.append(next_node1)
                    if next_node2 not in closed_list:
                        open_list.append(next_node2)
                    
            tab3, tab4 = tableau.copy(), tableau.copy()
            tab3.apply_S(i)
            tab4.apply_H(i)
            next_node3, next_node4 = tab3.return_string(), tab4.return_string()
            digraph.add_edge(node, next_node3, weight =0, label=("S", i))
            digraph.add_edge(node, next_node4, weight =0, label=("H", i))
            if next_node3 not in closed_list:
                open_list.append(next_node3)
            if next_node4 not in closed_list:
                open_list.append(next_node4)

# %%
G = nx.DiGraph()
graph_creator("XX", G)

# %%
pos = layout=nx.spring_layout(G, scale=10)
nx.draw(G, with_labels=True)

# %%
DG = nx.DiGraph()
graph_creator("XXX", DG)

# %%
pos = layout=nx.spring_layout(DG, scale=10)
nx.draw(DG, pos, with_labels=True)

# %%
len(DG.nodes())
# Out:
# 126

# %%
random_pauli = rnd.sample(list(DG.nodes()), 20)
random_pauli
# Out:
# ['-YZZ',
#  'XXX',
#  '-XYI',
#  '-YYZ',
#  'IYZ',
#  'ZYX',
#  '-IIX',
#  'YZX',
#  'ZZZ',
#  'YYI',
#  'ZZI',
#  'YIZ',
#  '-YYY',
#  'XYI',
#  '-IXI',
#  'XZI',
#  'XIY',
#  '-IXX',
#  'IZI',
#  'XIZ']

# %%
targets = [
    "IIZ",
    "IZI",
    "ZII",
    "-IIZ",
    "-IZI",
    "-ZII",
]

# %%
for pauli in random_pauli:
    print(f"paths from {pauli}")
    for end in targets:
        operations = []
        path = nx.shortest_path(DG, source=pauli, target=end, weight='weight')
        print(path)
        for i in range(len(path)-1):
            operations.append(DG[path[i]][path[i+1]]['label'])
        print(operations)
        print(f"Number of CNOTs {nx.path_weight(DG, path, 'weight')}")
        print()
    print()
# Out:
# paths from -YZZ
# ['-YZZ', 'XZZ', 'ZZZ', 'IZZ', 'IIZ']
# [('S', 0), ('H', 0), ('CX', 0, 2), ('CX', 1, 2)]
# Number of CNOTs 2
#
# ['-YZZ', 'XZZ', 'ZZZ', 'IZZ', 'IZI']
# [('S', 0), ('H', 0), ('CX', 0, 2), ('CX', 2, 1)]
# Number of CNOTs 2
#
# ['-YZZ', '-YIZ', '-YII', 'XII', 'ZII']
# [('CX', 1, 2), ('CX', 2, 0), ('S', 0), ('H', 0)]
# Number of CNOTs 2
#
# ['-YZZ', 'XZZ', 'ZZZ', 'ZIZ', 'IIZ', 'IIX', 'IIY', '-IIX', '-IIZ']
# [('S', 0), ('H', 0), ('CX', 1, 2), ('CX', 0, 2), ('H', 2), ('S', 2), ('S', 2), ('H', 2)]
# Number of CNOTs 2
#
# ['-YZZ', 'XZZ', 'ZZZ', 'IZZ', 'IZI', 'IXI', 'IYI', '-IXI', '-IZI']
# [('S', 0), ('H', 0), ('CX', 0, 2), ('CX', 2, 1), ('H', 1), ('S', 1), ('S', 1), ('H', 1)]
# Number of CNOTs 2
#
# ['-YZZ', 'YZZ', 'YIZ', 'YII', '-XII', '-ZII']
# [('H', 0), ('CX', 1, 2), ('CX', 2, 0), ('S', 0), ('H', 0)]
# Number of CNOTs 2
#
#
# paths from XXX
# ['XXX', 'XIX', 'IIX', 'IIZ']
# [('CX', 2, 1), ('CX', 2, 0), ('H', 2)]
# Number of CNOTs 2
#
# ['XXX', 'IXX', 'IXI', 'IZI']
# [('CX', 2, 0), ('CX', 1, 2), ('H', 1)]
# Number of CNOTs 2
#
# ['XXX', 'XIX', 'XII', 'ZII']
# [('CX', 2, 1), ('CX', 0, 2), ('H', 0)]
# Number of CNOTs 2
#
# ['XXX', 'XIX', 'IIX', 'IIY', '-IIX', '-IIZ']
# [('CX', 2, 1), ('CX', 2, 0), ('S', 2), ('S', 2), ('H', 2)]
# Number of CNOTs 2
#
# ['XXX', 'XYX', 'IYX', 'IYI', '-IXI', '-IZI']
# [('S', 1), ('CX', 2, 0), ('CX', 1, 2), ('S', 1), ('H', 1)]
# Number of CNOTs 2
#
# ['XXX', 'YXX', 'YIX', 'YII', '-XII', '-ZII']
# [('S', 0), ('CX', 2, 1), ('CX', 0, 2), ('S', 0), ('H', 0)]
# Number of CNOTs 2
#
#
# paths from -XYI
# ['-XYI', 'XXI', 'XXX', 'XIX', 'IIX', 'IIZ']
# [('S', 1), ('CX', 1, 2), ('CX', 2, 1), ('CX', 2, 0), ('H', 2)]
# Number of CNOTs 3
#
# ['-XYI', 'XXI', 'IXI', 'IZI']
# [('S', 1), ('CX', 1, 0), ('H', 1)]
# Number of CNOTs 1
#
# ['-XYI', 'XXI', 'XII', 'ZII']
# [('S', 1), ('CX', 0, 1), ('H', 0)]
# Number of CNOTs 1
#
# ['-XYI', 'XYI', '-XXI', '-XII', '-XIX', '-IIX', '-IIZ']
# [('H', 1), ('S', 1), ('CX', 0, 1), ('CX', 0, 2), ('CX', 2, 0), ('H', 2)]
# Number of CNOTs 3
#
# ['-XYI', 'XYI', 'IYI', '-IXI', '-IZI']
# [('H', 1), ('CX', 1, 0), ('S', 1), ('H', 1)]
# Number of CNOTs 1
#
# ['-XYI', '-YYI', 'YXI', 'YII', '-XII', '-ZII']
# [('S', 0), ('S', 1), ('CX', 0, 1), ('S', 0), ('H', 0)]
# Number of CNOTs 1
#
#
# paths from -YYZ
# ['-YYZ', 'XYZ', '-XXZ', '-XXX', '-XIX', '-IIX', '-IIY', 'IIX', 'IIZ']
# [('S', 0), ('S', 1), ('H', 2), ('CX', 2, 1), ('CX', 2, 0), ('S', 2), ('S', 2), ('H', 2)]
# Number of CNOTs 2
#
# ['-YYZ', 'XYZ', 'XYI', 'IYI', '-IYI', 'IXI', 'IZI']
# [('S', 0), ('CX', 2, 1), ('CX', 1, 0), ('H', 1), ('S', 1), ('H', 1)]
# Number of CNOTs 2
#
# ['-YYZ', 'YXZ', 'YXI', 'YII', '-YII', 'XII', 'ZII']
# [('S', 1), ('CX', 2, 0), ('CX', 0, 1), ('H', 0), ('S', 0), ('H', 0)]
# Number of CNOTs 2
#
# ['-YYZ', 'XYZ', '-XXZ', '-XIZ', '-ZIZ', '-IIZ']
# [('S', 0), ('S', 1), ('CX', 0, 1), ('H', 0), ('CX', 0, 2)]
# Number of CNOTs 2
#
# ['-YYZ', 'XYZ', 'XYI', 'IYI', '-IXI', '-IZI']
# [('S', 0), ('CX', 2, 1), ('CX', 1, 0), ('S', 1), ('H', 1)]
# Number of CNOTs 2
#
# ['-YYZ', 'YXZ', 'YIZ', 'YII', '-XII', '-ZII']
# [('S', 1), ('CX', 0, 1), ('CX', 2, 0), ('S', 0), ('H', 0)]
# Number of CNOTs 2
#
#
# paths from IYZ
# ['IYZ', '-IXZ', '-IXX', '-IIX', '-IIY', 'IIX', 'IIZ']
# [('S', 1), ('H', 2), ('CX', 2, 1), ('S', 2), ('S', 2), ('H', 2)]
# Number of CNOTs 1
#
# ['IYZ', '-IYZ', '-IYI', 'IXI', 'IZI']
# [('H', 1), ('CX', 2, 1), ('S', 1), ('H', 1)]
# Number of CNOTs 1
#
# ['IYZ', '-IYZ', 'IXZ', 'IZZ', 'ZZZ', 'ZIZ', 'ZII']
# [('H', 1), ('S', 1), ('H', 1), ('CX', 0, 2), ('CX', 1, 2), ('CX', 2, 0)]
# Number of CNOTs 3
#
# ['IYZ', '-IXZ', '-IZZ', '-IIZ']
# [('S', 1), ('H', 1), ('CX', 1, 2)]
# Number of CNOTs 1
#
# ['IYZ', '-IXZ', '-IZZ', '-IZI']
# [('S', 1), ('H', 1), ('CX', 2, 1)]
# Number of CNOTs 1
#
# ['IYZ', '-IXZ', '-IZZ', '-IIZ', '-ZIZ', '-ZII']
# [('S', 1), ('H', 1), ('CX', 1, 2), ('CX', 0, 2), ('CX', 2, 0)]
# Number of CNOTs 3
#
#
# paths from ZYX
# ['ZYX', 'XYX', '-XXX', '-XIX', '-IIX', '-IIY', 'IIX', 'IIZ']
# [('H', 0), ('S', 1), ('CX', 2, 1), ('CX', 2, 0), ('S', 2), ('S', 2), ('H', 2)]
# Number of CNOTs 2
#
# ['ZYX', '-ZYX', '-IYX', '-IYI', 'IXI', 'IZI']
# [('H', 1), ('CX', 0, 1), ('CX', 1, 2), ('S', 1), ('H', 1)]
# Number of CNOTs 2
#
# ['ZYX', 'XYX', '-XXX', '-XIX', '-XII', '-YII', 'XII', 'ZII']
# [('H', 0), ('S', 1), ('CX', 2, 1), ('CX', 0, 2), ('S', 0), ('S', 0), ('H', 0)]
# Number of CNOTs 2
#
# ['ZYX', '-ZXX', '-ZIX', '-ZIZ', '-IIZ']
# [('S', 1), ('CX', 2, 1), ('H', 2), ('CX', 0, 2)]
# Number of CNOTs 2
#
# ['ZYX', 'IYX', 'IYI', '-IXI', '-IZI']
# [('CX', 0, 1), ('CX', 1, 2), ('S', 1), ('H', 1)]
# Number of CNOTs 2
#
# ['ZYX', '-ZXX', '-ZIX', '-ZIZ', '-ZII']
# [('S', 1), ('CX', 2, 1), ('H', 2), ('CX', 2, 0)]
# Number of CNOTs 2
#
#
# paths from -IIX
# ['-IIX', '-IIY', 'IIX', 'IIZ']
# [('S', 2), ('S', 2), ('H', 2)]
# Number of CNOTs 0
#
# ['-IIX', '-IIY', 'IIX', 'IXX', 'IXI', 'IZI']
# [('S', 2), ('S', 2), ('CX', 2, 1), ('CX', 1, 2), ('H', 1)]
# Number of CNOTs 2
#
# ['-IIX', '-IIY', 'IIX', 'XIX', 'XII', 'ZII']
# [('S', 2), ('S', 2), ('CX', 2, 0), ('CX', 0, 2), ('H', 0)]
# Number of CNOTs 2
#
# ['-IIX', '-IIZ']
# [('H', 2)]
# Number of CNOTs 0
#
# ['-IIX', '-IXX', '-IXI', '-IZI']
# [('CX', 2, 1), ('CX', 1, 2), ('H', 1)]
# Number of CNOTs 2
#
# ['-IIX', '-XIX', '-XII', '-ZII']
# [('CX', 2, 0), ('CX', 0, 2), ('H', 0)]
# Number of CNOTs 2
#
#
# paths from YZX
# ['YZX', '-XZX', '-XXX', '-XIX', '-IIX', '-IIY', 'IIX', 'IIZ']
# [('S', 0), ('H', 1), ('CX', 2, 1), ('CX', 2, 0), ('S', 2), ('S', 2), ('H', 2)]
# Number of CNOTs 2
#
# ['YZX', '-XZX', '-XXX', '-IXX', '-IXI', '-IYI', 'IXI', 'IZI']
# [('S', 0), ('H', 1), ('CX', 2, 0), ('CX', 1, 2), ('S', 1), ('S', 1), ('H', 1)]
# Number of CNOTs 2
#
# ['YZX', '-YZX', '-YIX', '-YII', 'XII', 'ZII']
# [('H', 0), ('CX', 1, 0), ('CX', 0, 2), ('S', 0), ('H', 0)]
# Number of CNOTs 2
#
# ['YZX', '-XZX', '-ZZX', '-ZIX', '-ZIZ', '-IIZ']
# [('S', 0), ('H', 0), ('CX', 1, 0), ('H', 2), ('CX', 0, 2)]
# Number of CNOTs 2
#
# ['YZX', '-XZX', '-IZX', '-IZZ', '-IZI']
# [('S', 0), ('CX', 2, 0), ('H', 2), ('CX', 2, 1)]
# Number of CNOTs 2
#
# ['YZX', 'YIX', 'YII', '-XII', '-ZII']
# [('CX', 1, 0), ('CX', 0, 2), ('S', 0), ('H', 0)]
# Number of CNOTs 2
#
#
# paths from ZZZ
# ['ZZZ', 'ZIZ', 'IIZ']
# [('CX', 1, 2), ('CX', 0, 2)]
# Number of CNOTs 2
#
# ['ZZZ', 'IZZ', 'IZI']
# [('CX', 0, 2), ('CX', 2, 1)]
# Number of CNOTs 2
#
# ['ZZZ', 'ZIZ', 'ZII']
# [('CX', 1, 2), ('CX', 2, 0)]
# Number of CNOTs 2
#
# ['ZZZ', 'ZIZ', 'IIZ', 'IIX', 'IIY', '-IIX', '-IIZ']
# [('CX', 1, 2), ('CX', 0, 2), ('H', 2), ('S', 2), ('S', 2), ('H', 2)]
# Number of CNOTs 2
#
# ['ZZZ', 'IZZ', 'IZI', 'IXI', 'IYI', '-IXI', '-IZI']
# [('CX', 0, 2), ('CX', 2, 1), ('H', 1), ('S', 1), ('S', 1), ('H', 1)]
# Number of CNOTs 2
#
# ['ZZZ', 'XZZ', 'YZZ', 'YIZ', 'YII', '-XII', '-ZII']
# [('H', 0), ('S', 0), ('CX', 1, 2), ('CX', 2, 0), ('S', 0), ('H', 0)]
# Number of CNOTs 2
#
#
# paths from YYI
# ['YYI', '-XYI', 'XXI', 'XXX', 'XIX', 'IIX', 'IIZ']
# [('S', 0), ('S', 1), ('CX', 1, 2), ('CX', 2, 1), ('CX', 2, 0), ('H', 2)]
# Number of CNOTs 3
#
# ['YYI', '-XYI', 'XXI', 'IXI', 'IZI']
# [('S', 0), ('S', 1), ('CX', 1, 0), ('H', 1)]
# Number of CNOTs 1
#
# ['YYI', '-XYI', 'XXI', 'XII', 'ZII']
# [('S', 0), ('S', 1), ('CX', 0, 1), ('H', 0)]
# Number of CNOTs 1
#
# ['YYI', '-XYI', 'XYI', '-XXI', '-XII', '-XIX', '-IIX', '-IIZ']
# [('S', 0), ('H', 1), ('S', 1), ('CX', 0, 1), ('CX', 0, 2), ('CX', 2, 0), ('H', 2)]
# Number of CNOTs 3
#
# ['YYI', '-XYI', 'XYI', 'IYI', '-IXI', '-IZI']
# [('S', 0), ('H', 1), ('CX', 1, 0), ('S', 1), ('H', 1)]
# Number of CNOTs 1
#
# ['YYI', '-YYI', 'YXI', 'YII', '-XII', '-ZII']
# [('H', 1), ('S', 1), ('CX', 0, 1), ('S', 0), ('H', 0)]
# Number of CNOTs 1
#
#
# paths from ZZI
# ['ZZI', 'ZII', 'ZIZ', 'IIZ']
# [('CX', 1, 0), ('CX', 2, 0), ('CX', 0, 2)]
# Number of CNOTs 3
#
# ['ZZI', 'IZI']
# [('CX', 0, 1)]
# Number of CNOTs 1
#
# ['ZZI', 'ZII']
# [('CX', 1, 0)]
# Number of CNOTs 1
#
# ['ZZI', 'XZI', 'YZI', '-XZI', '-ZZI', '-IZI', '-IZZ', '-IIZ']
# [('H', 0), ('S', 0), ('S', 0), ('H', 0), ('CX', 0, 1), ('CX', 2, 1), ('CX', 1, 2)]
# Number of CNOTs 3
#
# ['ZZI', 'ZXI', 'ZYI', 'IYI', '-IXI', '-IZI']
# [('H', 1), ('S', 1), ('CX', 0, 1), ('S', 1), ('H', 1)]
# Number of CNOTs 1
#
# ['ZZI', 'XZI', 'YZI', 'YII', '-XII', '-ZII']
# [('H', 0), ('S', 0), ('CX', 1, 0), ('S', 0), ('H', 0)]
# Number of CNOTs 1
#
#
# paths from YIZ
# ['YIZ', '-XIZ', '-XIX', '-IIX', '-IIY', 'IIX', 'IIZ']
# [('S', 0), ('H', 2), ('CX', 2, 0), ('S', 2), ('S', 2), ('H', 2)]
# Number of CNOTs 1
#
# ['YIZ', '-YIZ', 'XIZ', 'ZIZ', 'ZZZ', 'IZZ', 'IZI']
# [('H', 0), ('S', 0), ('H', 0), ('CX', 1, 2), ('CX', 0, 2), ('CX', 2, 1)]
# Number of CNOTs 3
#
# ['YIZ', '-YIZ', '-YII', 'XII', 'ZII']
# [('H', 0), ('CX', 2, 0), ('S', 0), ('H', 0)]
# Number of CNOTs 1
#
# ['YIZ', '-XIZ', '-ZIZ', '-IIZ']
# [('S', 0), ('H', 0), ('CX', 0, 2)]
# Number of CNOTs 1
#
# ['YIZ', '-XIZ', '-ZIZ', '-IIZ', '-IZZ', '-IZI']
# [('S', 0), ('H', 0), ('CX', 0, 2), ('CX', 1, 2), ('CX', 2, 1)]
# Number of CNOTs 3
#
# ['YIZ', '-XIZ', '-ZIZ', '-ZII']
# [('S', 0), ('H', 0), ('CX', 2, 0)]
# Number of CNOTs 1
#
#
# paths from -YYY
# ['-YYY', 'XYY', '-XXY', '-XIY', '-IIY', 'IIX', 'IIZ']
# [('S', 0), ('S', 1), ('CX', 2, 1), ('CX', 2, 0), ('S', 2), ('H', 2)]
# Number of CNOTs 2
#
# ['-YYY', 'XYY', '-XYX', '-IYX', '-IYI', 'IXI', 'IZI']
# [('S', 0), ('S', 2), ('CX', 2, 0), ('CX', 1, 2), ('S', 1), ('H', 1)]
# Number of CNOTs 2
#
# ['-YYY', 'XYY', '-XXY', 'XXX', 'XIX', 'XII', 'ZII']
# [('S', 0), ('S', 1), ('S', 2), ('CX', 2, 1), ('CX', 0, 2), ('H', 0)]
# Number of CNOTs 2
#
# ['-YYY', 'XYY', '-XXY', '-XIY', '-IIY', 'IIY', '-IIX', '-IIZ']
# [('S', 0), ('S', 1), ('CX', 2, 1), ('CX', 2, 0), ('H', 2), ('S', 2), ('H', 2)]
# Number of CNOTs 2
#
# ['-YYY', 'XYY', '-XYX', '-IYX', '-IYI', 'IYI', '-IXI', '-IZI']
# [('S', 0), ('S', 2), ('CX', 2, 0), ('CX', 1, 2), ('H', 1), ('S', 1), ('H', 1)]
# Number of CNOTs 2
#
# ['-YYY', 'YYY', '-YXY', 'YXX', 'YIX', 'YII', '-XII', '-ZII']
# [('H', 2), ('S', 1), ('S', 2), ('CX', 2, 1), ('CX', 0, 2), ('S', 0), ('H', 0)]
# Number of CNOTs 2
#
#
# paths from XYI
# ['XYI', '-XYI', 'XXI', 'XII', 'XIX', 'IIX', 'IIZ']
# [('H', 1), ('S', 1), ('CX', 0, 1), ('CX', 0, 2), ('CX', 2, 0), ('H', 2)]
# Number of CNOTs 3
#
# ['XYI', 'IYI', '-IYI', 'IXI', 'IZI']
# [('CX', 1, 0), ('H', 1), ('S', 1), ('H', 1)]
# Number of CNOTs 1
#
# ['XYI', 'YYI', '-YXI', '-YII', 'XII', 'ZII']
# [('S', 0), ('S', 1), ('CX', 0, 1), ('S', 0), ('H', 0)]
# Number of CNOTs 1
#
# ['XYI', '-XXI', '-XXX', '-XIX', '-IIX', '-IIZ']
# [('S', 1), ('CX', 1, 2), ('CX', 2, 1), ('CX', 2, 0), ('H', 2)]
# Number of CNOTs 3
#
# ['XYI', 'IYI', '-IXI', '-IZI']
# [('CX', 1, 0), ('S', 1), ('H', 1)]
# Number of CNOTs 1
#
# ['XYI', '-XXI', '-XII', '-ZII']
# [('S', 1), ('CX', 0, 1), ('H', 0)]
# Number of CNOTs 1
#
#
# paths from -IXI
# ['-IXI', '-IYI', 'IXI', 'IXX', 'IIX', 'IIZ']
# [('S', 1), ('S', 1), ('CX', 1, 2), ('CX', 2, 1), ('H', 2)]
# Number of CNOTs 2
#
# ['-IXI', '-IYI', 'IXI', 'IZI']
# [('S', 1), ('S', 1), ('H', 1)]
# Number of CNOTs 0
#
# ['-IXI', '-IYI', 'IXI', 'XXI', 'XII', 'ZII']
# [('S', 1), ('S', 1), ('CX', 1, 0), ('CX', 0, 1), ('H', 0)]
# Number of CNOTs 2
#
# ['-IXI', '-IXX', '-IIX', '-IIZ']
# [('CX', 1, 2), ('CX', 2, 1), ('H', 2)]
# Number of CNOTs 2
#
# ['-IXI', '-IZI']
# [('H', 1)]
# Number of CNOTs 0
#
# ['-IXI', '-XXI', '-XII', '-ZII']
# [('CX', 1, 0), ('CX', 0, 1), ('H', 0)]
# Number of CNOTs 2
#
#
# paths from XZI
# ['XZI', 'ZZI', 'ZII', 'ZIZ', 'IIZ']
# [('H', 0), ('CX', 1, 0), ('CX', 2, 0), ('CX', 0, 2)]
# Number of CNOTs 3
#
# ['XZI', 'ZZI', 'IZI']
# [('H', 0), ('CX', 0, 1)]
# Number of CNOTs 1
#
# ['XZI', 'ZZI', 'ZII']
# [('H', 0), ('CX', 1, 0)]
# Number of CNOTs 1
#
# ['XZI', 'YZI', '-XZI', '-ZZI', '-IZI', '-IZZ', '-IIZ']
# [('S', 0), ('S', 0), ('H', 0), ('CX', 0, 1), ('CX', 2, 1), ('CX', 1, 2)]
# Number of CNOTs 3
#
# ['XZI', 'XXI', 'IXI', 'IYI', '-IXI', '-IZI']
# [('H', 1), ('CX', 1, 0), ('S', 1), ('S', 1), ('H', 1)]
# Number of CNOTs 1
#
# ['XZI', 'YZI', 'YII', '-XII', '-ZII']
# [('S', 0), ('CX', 1, 0), ('S', 0), ('H', 0)]
# Number of CNOTs 1
#
#
# paths from XIY
# ['XIY', 'IIY', '-IIY', 'IIX', 'IIZ']
# [('CX', 2, 0), ('H', 2), ('S', 2), ('H', 2)]
# Number of CNOTs 1
#
# ['XIY', '-XIY', 'XIX', 'XXX', 'IXX', 'IXI', 'IZI']
# [('H', 2), ('S', 2), ('CX', 2, 1), ('CX', 2, 0), ('CX', 1, 2), ('H', 1)]
# Number of CNOTs 3
#
# ['XIY', 'YIY', '-YIX', '-YII', 'XII', 'ZII']
# [('S', 0), ('S', 2), ('CX', 0, 2), ('S', 0), ('H', 0)]
# Number of CNOTs 1
#
# ['XIY', 'IIY', '-IIX', '-IIZ']
# [('CX', 2, 0), ('S', 2), ('H', 2)]
# Number of CNOTs 1
#
# ['XIY', '-XIX', '-XXX', '-IXX', '-IXI', '-IZI']
# [('S', 2), ('CX', 2, 1), ('CX', 2, 0), ('CX', 1, 2), ('H', 1)]
# Number of CNOTs 3
#
# ['XIY', '-XIX', '-XII', '-ZII']
# [('S', 2), ('CX', 0, 2), ('H', 0)]
# Number of CNOTs 1
#
#
# paths from -IXX
# ['-IXX', '-IYX', 'IXX', 'IIX', 'IIZ']
# [('S', 1), ('S', 1), ('CX', 2, 1), ('H', 2)]
# Number of CNOTs 1
#
# ['-IXX', '-IYX', 'IXX', 'IXI', 'IZI']
# [('S', 1), ('S', 1), ('CX', 1, 2), ('H', 1)]
# Number of CNOTs 1
#
# ['-IXX', '-IYX', 'IXX', 'XXX', 'XIX', 'XII', 'ZII']
# [('S', 1), ('S', 1), ('CX', 2, 0), ('CX', 2, 1), ('CX', 0, 2), ('H', 0)]
# Number of CNOTs 3
#
# ['-IXX', '-IIX', '-IIZ']
# [('CX', 2, 1), ('H', 2)]
# Number of CNOTs 1
#
# ['-IXX', '-IXI', '-IZI']
# [('CX', 1, 2), ('H', 1)]
# Number of CNOTs 1
#
# ['-IXX', '-XXX', '-XIX', '-XII', '-ZII']
# [('CX', 2, 0), ('CX', 2, 1), ('CX', 0, 2), ('H', 0)]
# Number of CNOTs 3
#
#
# paths from IZI
# ['IZI', 'IZZ', 'IIZ']
# [('CX', 2, 1), ('CX', 1, 2)]
# Number of CNOTs 2
#
# ['IZI']
# []
# Number of CNOTs 0
#
# ['IZI', 'ZZI', 'ZII']
# [('CX', 0, 1), ('CX', 1, 0)]
# Number of CNOTs 2
#
# ['IZI', 'IXI', 'IYI', '-IXI', '-IXX', '-IIX', '-IIZ']
# [('H', 1), ('S', 1), ('S', 1), ('CX', 1, 2), ('CX', 2, 1), ('H', 2)]
# Number of CNOTs 2
#
# ['IZI', 'IXI', 'IYI', '-IXI', '-IZI']
# [('H', 1), ('S', 1), ('S', 1), ('H', 1)]
# Number of CNOTs 0
#
# ['IZI', 'IXI', 'IYI', '-IXI', '-XXI', '-XII', '-ZII']
# [('H', 1), ('S', 1), ('S', 1), ('CX', 1, 0), ('CX', 0, 1), ('H', 0)]
# Number of CNOTs 2
#
#
# paths from XIZ
# ['XIZ', 'ZIZ', 'IIZ']
# [('H', 0), ('CX', 0, 2)]
# Number of CNOTs 1
#
# ['XIZ', 'ZIZ', 'IIZ', 'IZZ', 'IZI']
# [('H', 0), ('CX', 0, 2), ('CX', 1, 2), ('CX', 2, 1)]
# Number of CNOTs 3
#
# ['XIZ', 'ZIZ', 'ZII']
# [('H', 0), ('CX', 2, 0)]
# Number of CNOTs 1
#
# ['XIZ', 'XIX', 'IIX', 'IIY', '-IIX', '-IIZ']
# [('H', 2), ('CX', 2, 0), ('S', 2), ('S', 2), ('H', 2)]
# Number of CNOTs 1
#
# ['XIZ', 'YIZ', '-XIZ', '-ZIZ', '-ZZZ', '-IZZ', '-IZI']
# [('S', 0), ('S', 0), ('H', 0), ('CX', 1, 2), ('CX', 0, 2), ('CX', 2, 1)]
# Number of CNOTs 3
#
# ['XIZ', 'YIZ', 'YII', '-XII', '-ZII']
# [('S', 0), ('CX', 2, 0), ('S', 0), ('H', 0)]
# Number of CNOTs 1

# %% [markdown]
# The work above has shown that the amount of minimum CNOTs necessary to get an arbitrary Pauli String to being implementable is its Pauli weight - 1. This makes sense because the CNOTs remove only one Pauli at a time when applied on a reducible pair _("XX", "ZY", "YX", "ZZ")_. For a 4 qubit Pauli String you would need to remove 3 Paulis which would require 3 CNOTs. The S and H gates simply permute single qubit Paulis and so can be used to produce the necessary reducible pairs.

# %% [markdown]
# With this is mind the following steps can be taken:
#
# Given a Pauli String:
# * Apply CNOTs to reducible pairs
# * If Pauli weight == 1 -> stop return new Pauli String and list of operations
# * else -> convert first non X  Pauli to X with S or H, add operations to list and repeat

# %% [markdown]
# This works because it removes all the reducible pairs that exist in a Pauli string. There are only two situations where there will be no reducible pairs:
#
# * The remainder of the Paulis are Ys
# * There is one X and one Z left (if any other Pauli is present it will form a reducible pair with either the X or Z adn would be removed earlier)
#
# Converting the first non X to X will introduce a reducible pair -> either _"XX"_ or _"YX"_. Though the number of Hs and Ss is not being tracked this way only uses one S or H gate to convert and only does so for the first non X encountered. This will prevent overuse of Hs and Ss when converting from Z to Y for example.

# %%
def implementer(pauli_str: str):
    '''
    Function to convert a Pauli String to being implementable (Pauli weight of 1)

    :param pauli_str: string that represents a payli string
    '''

    # convert string into tableau because CX, H  and S operations are well defined in implementation
    tableau = Cirq_Tableau([pauli_str])

    # path to store operations done
    path = []

    # loop to continue until Pauli string is implementable 
    while True:

        # loop to apply CXs
        for i in range(tableau.column_num):
            if i != tableau.column_num -1:
                for j in range(i+1, tableau.column_num):
                    # conditions to check if Z Pauli is on control XOR X Pauli is on target and neither is I
                    if (~(tableau.xs[0][i]) & tableau.zs[0][i] & tableau.zs[0][j]) | (tableau.xs[0][i] & tableau.xs[0][j] & ~(tableau.zs[0][j])):
                        tableau.apply_CX(i,j)
                        path.append(("CX", i, j))
                    elif (~(tableau.xs[0][j]) & tableau.zs[0][j] & tableau.zs[0][i]) | (tableau.xs[0][j] & tableau.xs[0][i] & ~(tableau.zs[0][i])):
                        tableau.apply_CX(j, i)
                        path.append(("CX", j, i))
                        
        # Condition to check if Pauli String is implementable 
        if sum(tableau.xs[0] | tableau.zs[0]) == 1:
            break

        # loop to change first Y or Z encountered to X
        for i in range(tableau.column_num):
            if (tableau.xs[0][i] & tableau.zs[0][i]):
                tableau.apply_S(i)
                path.append(("S",i))
                break
            elif (~(tableau.xs[0][i]) & tableau.zs[0][i]):
                tableau.apply_H(i)
                path.append(("H",i))
                break

    return path, tableau.return_string()

# %%
a= "ZYXZX"
path, string = implementer(a)
print(string, path)
# Out:
# IYIII [('CX', 0, 1), ('CX', 1, 2), ('CX', 3, 1), ('CX', 1, 4)]

# %%
for pauli in random_pauli:
    path, string = implementer(pauli)
    print(f"path from {pauli} to {string}")
    print(path)
    print(f"Number of CNOTs {sum([1 for x in path if x[0] == "CX"])}")
    print()
# Out:
# path from -YZZ to -YII
# [('CX', 1, 0), ('CX', 2, 0)]
# Number of CNOTs 2
#
# path from XXX to XII
# [('CX', 0, 1), ('CX', 0, 2)]
# Number of CNOTs 2
#
# path from -XYI to -IYI
# [('CX', 1, 0)]
# Number of CNOTs 1
#
# path from -YYZ to IYI
# [('CX', 2, 0), ('S', 0), ('CX', 1, 0)]
# Number of CNOTs 2
#
# path from IYZ to IYI
# [('CX', 2, 1)]
# Number of CNOTs 1
#
# path from ZYX to IYI
# [('CX', 0, 1), ('CX', 1, 2)]
# Number of CNOTs 2
#
# path from -IIX to -IIX
# []
# Number of CNOTs 0
#
# path from YZX to YII
# [('CX', 1, 0), ('CX', 0, 2)]
# Number of CNOTs 2
#
# path from ZZZ to IIZ
# [('CX', 0, 1), ('CX', 1, 2)]
# Number of CNOTs 2
#
# path from YYI to -IYI
# [('S', 0), ('CX', 1, 0)]
# Number of CNOTs 1
#
# path from ZZI to IZI
# [('CX', 0, 1)]
# Number of CNOTs 1
#
# path from YIZ to YII
# [('CX', 2, 0)]
# Number of CNOTs 1
#
# path from -YYY to -IIY
# [('S', 0), ('CX', 1, 0), ('S', 1), ('CX', 2, 1)]
# Number of CNOTs 2
#
# path from XYI to IYI
# [('CX', 1, 0)]
# Number of CNOTs 1
#
# path from -IXI to -IXI
# []
# Number of CNOTs 0
#
# path from XZI to XII
# [('H', 1), ('CX', 0, 1)]
# Number of CNOTs 1
#
# path from XIY to IIY
# [('CX', 2, 0)]
# Number of CNOTs 1
#
# path from -IXX to -IXI
# [('CX', 1, 2)]
# Number of CNOTs 1
#
# path from IZI to IZI
# []
# Number of CNOTs 0
#
# path from XIZ to XII
# [('H', 2), ('CX', 0, 2)]
# Number of CNOTs 1
