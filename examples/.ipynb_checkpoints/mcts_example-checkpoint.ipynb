# %%
import os
import sys

# %%
# this adds the module to the path so that it can be used to call the functions
root = os.path.abspath(os.path.join(os.path.dirname(os.getcwd())))
sys.path.append(root)

# %%
from src.classes import Node, Cirq_Tableau
from src.heuristic_module import pair_solve
from src.mcts_module import full_circuit, p_word_solution, cx_count

# %%
from qiskit.circuit import QuantumCircuit

# %%
TIME = 10 # time parameter for tree search in seconds 
PARAM = 10 # UCT parameter

# %% [markdown]
# ## *Test Data*

# %% [markdown]
# ### commuting sets

# %%
ucc_2_4 = [
    [
        "YZXI",
        "XZXI",
        "YZYI",
        "XZYI"
    ],
    [
        "IYZX",
        "IXZX",
        "IYZY",
        "IXZY"
    ],
    [
        "YXYX",
        "XXYX",
        "YYYX",
        "XYYX",
        "YXYY",
        "XXYY",
        "YYYY",
        "XYYY",
        "YXXX",
        "XXXX",
        "YYXX",
        "XYXX",
        "YXXY",
        "XXXY",
        "YYXY",
        "XYXY"
    ]
]

ucc_2_6 = [
    [
        "YZXIII",
        "XZXIII",
        "YZYIII",
        "XZYIII"
    ],
    [
        "YZZZXI",
        "XZZZXI",
        "YZZZYI",
        "XZZZYI"
    ],
    [
        "IYZXII",
        "IXZXII",
        "IYZYII",
        "IXZYII"
    ],
    [
        "IYZZZX",
        "IXZZZX",
        "IYZZZY",
        "IXZZZY"
    ],
    [
        "YXYXII",
        "XXYXII",
        "YYYXII",
        "XYYXII",
        "YXYYII",
        "XXYYII",
        "YYYYII",
        "XYYYII",
        "YXXXII",
        "XXXXII",
        "YYXXII",
        "XYXXII",
        "YXXYII",
        "XXXYII",
        "YYXYII",
        "XYXYII"
    ],
    [
        "YXYZZX",
        "XXYZZX",
        "YYYZZX",
        "XYYZZX",
        "YXYZZY",
        "XXYZZY",
        "YYYZZY",
        "XYYZZY",
        "YXXZZX",
        "XXXZZX",
        "YYXZZX",
        "XYXZZX",
        "YXXZZY",
        "XXXZZY",
        "YYXZZY",
        "XYXZZY"
    ],
    [
        "YXIYXI",
        "XXIYXI",
        "YYIYXI",
        "XYIYXI",
        "YXIYYI",
        "XXIYYI",
        "YYIYYI",
        "XYIYYI",
        "YXIXXI",
        "XXIXXI",
        "YYIXXI",
        "XYIXXI",
        "YXIXYI",
        "XXIXYI",
        "YYIXYI",
        "XYIXYI"
    ],
    [
        "YXIIYX",
        "XXIIYX",
        "YYIIYX",
        "XYIIYX",
        "YXIIYY",
        "XXIIYY",
        "YYIIYY",
        "XYIIYY",
        "YXIIXX",
        "XXIIXX",
        "YYIIXX",
        "XYIIXX",
        "YXIIXY",
        "XXIIXY",
        "YYIIXY",
        "XYIIXY"
    ]
]

ucc_4_8 = [
    [
        "YZZZXIII",
        "XZZZXIII",
        "YZZZYIII",
        "XZZZYIII"
    ],
    [
        "YZZZZZXI",
        "XZZZZZXI",
        "YZZZZZYI",
        "XZZZZZYI"
    ],
    [
        "IYZZZXII",
        "IXZZZXII",
        "IYZZZYII",
        "IXZZZYII"
    ],
    [
        "IYZZZZZX",
        "IXZZZZZX",
        "IYZZZZZY",
        "IXZZZZZY"
    ],
    [
        "IIYZXIII",
        "IIXXYXII",
        "IIYYYXII",
        "IIXYYXII",
        "IIYXYYII",
        "IIXXYYII",
        "IIYYYYII",
        "IIXYYYII",
        "IIYXXXII",
        "IIXXXXII",
        "IIYYXXII",
        "IIXYXXII",
        "IIYXXYII",
        "IIXXXYII",
        "IIYYXYII",
        "IIXYXYII",
        "IIYXYZZX",
        "IIXXYZZX",
        "IIYYYZZX",
        "IIXYYZZX",
        "IIYXYZZY",
        "IIXXYZZY",
        "IIYYYZZY",
        "IIXYYZZY",
        "IIYXXZZX",
        "IIXXXZZX",
        "IIYYXZZX",
        "IIXYXZZX",
        "IIYXXZZY",
        "IIXXXZZY",
        "IIYYXZZY",
        "IIXYXZZY",
        "IIYXIYXI",
        "IIXXIYXI",
        "IIYYIYXI",
        "IIXYIYXI",
        "IIYXIYYI",
        "IIXXIYYI",
        "IIYYIYYI",
        "IIXYIYYI",
        "IIYXIXXI",
        "IIXXIXXI",
        "IIYYIXXI",
        "IIXYIXXI",
        "IIYXIXYI",
        "IIXXIXYI",
        "IIYYIXYI",
        "IIXYIXYI",
        "IIYXIIYX",
        "IIXXIIYX",
        "IIYYIIYX",
        "IIXYIIYX",
        "IIYXIIYY",
        "IIXXIIYY",
        "IIYYIIYY",
        "IIXYIIYY",
        "IIYXIIXX",
        "IIXXIIXX",
        "IIYYIIXX",
        "IIXYIIXX",
        "IIYXIIXY",
        "IIXXIIXY",
        "IIYYIIXY",
        "IIXYIIXY"
    ]

# %% [markdown]
# ## *Tests*

# %%
import random

# %%
def test_params(num_paulis, minim, maxim):
    params = []
    for i in range(num_paulis):
        prm = random.uniform(minim, maxim)
        while prm in params:
            prm = random.uniform(minim, maxim)
        params.append(prm)
    return params

# %%
tst_params = test_params(24, 0, 5)

# %%
pauli_word = Cirq_Tableau(ucc_2_4[2]) # Tableau form of a Pauli word 
solution = p_word_solution(pauli_word, pair_solve, PARAM, TIME)
solution
# Out:
# [('CX', 0, 1),
#  ('S', 0),
#  ('S', 2),
#  ('CX', 0, 2),
#  ('CX', 0, 3),
#  ('X', 0),
#  ('-Y', 0),
#  ('H', 1),
#  ('CX', 0, 1),
#  ('Y', 0),
#  ('X', 0),
#  ('S', 0),
#  ('H', 2),
#  ('CX', 0, 2),
#  ('Y', 0),
#  ('X', 0),
#  ('CX', 0, 1),
#  ('X', 0),
#  ('-Y', 0),
#  ('H', 3),
#  ('CX', 0, 3),
#  ('Y', 0),
#  ('X', 0),
#  ('CX', 0, 2),
#  ('-X', 0),
#  ('Y', 0),
#  ('CX', 0, 1),
#  ('-Y', 0),
#  ('-X', 0),
#  ('CX', 0, 2),
#  ('-X', 0),
#  ('Y', 0)]

# %%
cx_count(solution)
# Out:
# 10

# %%
r_params = test_params(sum([len(x) for x in ucc_2_4]), 0, 5)
r_params
# Out:
# [2.9558045288392103,
#  0.8184647152777969,
#  0.30271093262485893,
#  2.0380039248328568,
#  2.8001615975659657,
#  3.9061972868574033,
#  1.5475892823851072,
#  3.8515943289443215,
#  0.28092362534909987,
#  3.6482062671959135,
#  2.337053633165488,
#  3.8839176390479753,
#  0.025680387830833706,
#  2.4001617251676723,
#  3.0380833120875828,
#  0.5111909477665944,
#  0.11963178234532856,
#  1.321108310861307,
#  3.1733813500099273,
#  4.863739905804222,
#  1.0567955703243288,
#  4.219437677781237,
#  1.1249233515995067,
#  0.10515506649486639]

# %%
circuit = full_circuit(ucc_2_4, pair_solve, PARAM, TIME,rot_params=r_params, gate_cancellation=True)
circuit.draw('mpl')

# %%
circuit.count_ops()['cx']
# Out:
# 22

# %%
from qiskit.circuit.library import PauliEvolutionGate
from qiskit.circuit import ParameterVector
from qiskit.quantum_info import SparsePauliOp, Pauli
from qiskit.transpiler.passes.synthesis.hls_plugins import PauliEvolutionSynthesisRustiq
from qiskit.transpiler.passes import CommutativeCancellation
from qiskit.converters import circuit_to_dag, dag_to_circuit
import numpy as np

# %%
y = "YXZI"
list(y)
# Out:
# ['Y', 'X', 'Z', 'I']

# %%
def create_op(p_string):
    operator = None
    p_list = list(p_string)
    for p in p_list:
        if operator == None:
            operator = SparsePauliOp(p)
        else:
            operator = operator ^ SparsePauliOp(p)
    return operator

# %%
def rustiq_solve(p_word, params=None, order=True, gate_cancellation=True):
    operator = None
    if params == None:
        params = [0.01*i for i in range(1, len(p_word)+1)]
    for i, pauli in enumerate(p_word):
        if operator == None:
            op = create_op(pauli)
            operator =  op
            print(operator)
        else:
            op = create_op(pauli)
            operator = operator + (op)
            print(operator)

    
    evolution = PauliEvolutionGate(operator, time = 1)
    cirq = PauliEvolutionSynthesisRustiq().run(evolution,preserve_order=order,upto_phase=True, resynth_clifford_method=2, fix_clifford=True)
    if gate_cancellation:
        cirq = dag_to_circuit(
            CommutativeCancellation().run(
                circuit_to_dag(cirq)
            )
        )

    return cirq

# %%
rust_cirq = rustiq_solve(ucc_2_4_whole)
rust_cirq.draw('mpl')
# Out:
# SparsePauliOp(['YZXI'],
#               coeffs=[1.+0.j])
# SparsePauliOp(['YZXI', 'XZXI'],
#               coeffs=[1.+0.j, 1.+0.j])
# SparsePauliOp(['YZXI', 'XZXI', 'YZYI'],
#               coeffs=[1.+0.j, 1.+0.j, 1.+0.j])
# SparsePauliOp(['YZXI', 'XZXI', 'YZYI', 'XZYI'],
#               coeffs=[1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j])
# SparsePauliOp(['YZXI', 'XZXI', 'YZYI', 'XZYI', 'IYZX'],
#               coeffs=[1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j])
# SparsePauliOp(['YZXI', 'XZXI', 'YZYI', 'XZYI', 'IYZX', 'IXZX'],
#               coeffs=[1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j])
# SparsePauliOp(['YZXI', 'XZXI', 'YZYI', 'XZYI', 'IYZX', 'IXZX', 'IYZY'],
#               coeffs=[1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j])
# SparsePauliOp(['YZXI', 'XZXI', 'YZYI', 'XZYI', 'IYZX', 'IXZX', 'IYZY', 'IXZY'],
#               coeffs=[1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j])
# ...

# %%
rust_cirq.count_ops()['cx']
# Out:
# 34

# %%
from rustiq import pauli_network_synthesis, Metric
from rustiq.utils import entangling_count, entangling_depth

# %%
circuit = pauli_network_synthesis(ucc_2_4_whole, Metric("count"), True, fix_clifford=False)
entangling_count(circuit)
# Out:
# 26
